# %% [markdown]
# # Google Colab · Drive 연결 확인
#
# 아래 셀을 Colab에서 실행하고 Colab에 로그인한 것과 동일한 Google 계정으로 연결을 승인하세요. 성공하면 `Mounted at /content/drive` 또는 이미 연결되었다는 메시지가 표시됩니다.
#
# 이 두 줄에서도 계정 승인 팝업에 401 오류가 나타나면 브라우저·계정·Colab 인증 흐름을 점검해야 합니다. 이 노트북 자체가 인증 오류를 해결하는 것은 아닙니다. 오류 팝업을 닫고 Chrome의 새 프로필에서 사용할 계정 하나로 로그인한 뒤 확인해 보세요.
#
# 연결이 성공하면 예측 노트북을 열고 전체 실행하세요. 노트북마다 런타임이 다를 수 있으므로 예측 노트북에서 다시 연결 승인을 요청할 수 있습니다.
#
# [Colab 공식 FAQ](https://research.google.com/colaboratory/faq.html)

# %%
from google.colab import drive
drive.mount("/content/drive")
